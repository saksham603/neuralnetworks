# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
    return 2*x**2 + 3*x +4

# %%
f(2)
# Out:
# 18

# %%
xs = np.arange(-10, 10, 0.25)
ys = f(xs)
plt.plot(xs,ys)

# %%
h = 0.000000001
x = 2
(f(x + h) - f(x)) / h
# Out:
# 11.000000910144081
